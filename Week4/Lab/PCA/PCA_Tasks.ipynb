# %% [markdown]
# ## This Exercise is to implement PCA

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
# Task-1: Read the Iris dataset from the following Url and use the 
# following names = ['sepal length','sepal width','petal length','petal width','target']
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df = pd.read_csv(url, names=['sepal length','sepal width','petal length','petal width','target'])
df.head()

# %%
# Task-2: extract the features into variable x, 
# i.e. the values of the first four columns
features = ['sepal length', 'sepal width', 'petal length', 'petal width']

x = df[features].values # these are the variables (the 4 dimensions)
y = df['target'].values

# %%
# Task-3: standardize the data in x matrix
# using the StandardScaler().fit_transform function, 
# and save the results in a new variable
scaled_x = StandardScaler().fit_transform(x)

# %%
# Task-4: Calculate and print the covariance matrix for the scaled data using np.cov function

# %%
# Task-6: calculate and print Eigenvalues and vectors for the covariance Matrix 
# using the function np.linalg.eig(C). 
# note that this function will return two results,
# the eValues and eVectors. print these results

# %%
# Task-7: compute the percentage of information (variance) 
# preserved by each component , Hint: use the eValues

DataInformation = eValue/sum(eValue)
print("percentage of information (variance)preserved by each component is: ")
print(DataInformation)
print()
print("total information is: ")
print(sum(DataInformation))

# %%
# Task-8: reduce the original data dimensions into 1D instead of 4D. 
# this is done by multiplying the selected PCA component (eVector) 
# with the original scaled data 
# what is the size of the new data?
# What is the percentage of information loss?

# %%
# Task-9: reduce the original data dimensions into 2D instead of 4D. 
# this is done by multiplying the selected PCA components (eVectors) with the original scaled data 
# what is the size of the new data?
# What is the percentage of information loss?

# %%
# Task-10: in this task we will apply the PCA method provided by python sklearn, 
# compare the results with the previous results.
from sklearn.decomposition import PCA
