# %% [markdown]
# # Part 1: Dataset Files
# ### In this part, we will read and write to different dataset files using Python open library.
#
# #### Dataset with txt

# %%
# Writing data to a Text file, apply the write code in slide 11.
# check the content of the file

with open('accounts.txt', mode='w') as accounts:
    accounts.write('100 Jones 24.98\n')
    accounts.write('200 Doe 345.67\n')
    accounts.write('300 White 0.00\n')
    accounts.write('400 Stone -42.16\n')
    accounts.write('500 Rich 224.62\n')
    print('600 Jones 24.98', file=accounts)

# %%
# Reading data from a Text File, apply the read code in slide 12
with open('accounts.txt', mode='r') as accounts:
    print(f'{"Account":<10}{"Name":<10}{"Balance":>10}')
    for record in accounts:
        account, name, balance = record.split()
        print(f'{account:<10}{name:<10}{balance:>10}')
# Out:
# Account   Name         Balance
# 100       Jones          24.98
# 200       Doe           345.67
# 300       White           0.00
# 400       Stone         -42.16
# 500       Rich          224.62
# 600       Jones          24.98

# %% [markdown]
# #### Dataset with JSON

# %%
# Writing data to a josn file, apply the write code in slides 15 and 16.
accounts_dict = {'accounts': [
    {'account': 100, 'name': 'Jones', 'balance': 24.98},
    {'account': 200, 'name': 'Doe', 'balance': 345.67}]}

import json
with open('accounts.json', 'w') as accounts:
    json.dump(accounts_dict, accounts)

# %%
# Reading data from a josn file, apply the read code in slide 17
with open('accounts.json', 'r') as accounts:
    accounts_json = json.load(accounts)

accounts_json # show the full data as object
accounts_json['accounts'] # show all data rows
accounts_json['accounts'][0] # first rwo
accounts_json['accounts'][1] # second row
# Out:
# {'account': 200, 'name': 'Doe', 'balance': 345.67}

# %%
# Try the dumps function in slide 18
with open('accounts.json', 'r') as accounts:
    print(json.dumps(json.load(accounts), indent=4))
# Out:
# {
#     "accounts": [
#         {
#             "account": 100,
#             "name": "Jones",
#             "balance": 24.98
#         },
#         {
#             "account": 200,
#             "name": "Doe",
#             "balance": 345.67
#         }
#     ]
# }

# %% [markdown]
# #### Dataset with CSV

# %%
# Writing data to a csv file, apply the write code in slide 20.

import csv
with open('accounts.csv', mode='w', newline='') as accounts:
    writer = csv.writer(accounts)
    writer.writerow([100, 'Jones', 24.98])
    writer.writerow([200, 'Doe', 345.67])
    writer.writerow([300, 'White', 0.00])
    writer.writerow([400, 'Stone', -42.16])
    writer.writerow([500, 'Rich', 224.62])

# %%
# Reading data from a csv file, apply the read code in slide 21. Note that it's similar to a txt file; however, no split function
with open('accounts.csv', 'r', newline='') as accounts:
    print(f'{"Account":<10}{"Name":<10}{"Balance":>10}')
    reader = csv.reader(accounts)
    for record in reader:  
        account, name, balance = record
        print(f'{account:<10}{name:<10}{balance:>10}')
# Out:
# Account   Name         Balance
# 100       Jones          24.98
# 200       Doe           345.67
# 300       White            0.0
# 400       Stone         -42.16
# 500       Rich          224.62
