# %%
# import the required libraries
import PIL # python image library
import PIL.Image
import tensorflow as tf
import pathlib # to manage the dataset path

# %%
# define the data path to access the dataset
data_dir = pathlib.Path('D1')
print(data_dir)
# print the number of images in the dataset
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# D1
# 112

# %%
# split into train and test datasets with following parameters
batch_size = 6
img_height = 244
img_width = 244

# image size: Size to resize images to after they are read from disk
# batch_size: Size of the batches of data.If None, the data will not be batched (the dataset will yield individual samples).
# Seed : Optional random seed for shuffling .
# validation_split: Optional float between 0 and 1, fraction of data to reserve for validation
# subset: One of "training" or "validation". Only used if validation_split is set
# class_names: This is the explicit list of class names (must match names of subdirectories).

# train data
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.3,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

#test data
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.3,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 112 files belonging to 8 classes.
# Using 79 files for training.
# Found 112 files belonging to 8 classes.
# Using 33 files for validation.

# %%
num_classes = 8 # number of labels (classes) in or dataset

# class Rescaling: A preprocessing layer which rescales input values to a new range used ot normalise the image pixel values to be between 0 and 1. 

# # Flatten(): reshapes the tensor to have a shape that is equal to the number
## of elements contained in the tensor. This is the same thing as making a 1d-array of elements
model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(16, 3, activation='relu'), # number of filters and the filter size
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(16, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(16, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(), 
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

# %%
model.compile(
  optimizer='adam',
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
#train the model
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=8
)
# Out:
# Epoch 1/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.1901 - loss: 2.0750 - val_accuracy: 0.2121 - val_loss: 2.0745
# Epoch 2/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.3647 - loss: 1.9834 - val_accuracy: 0.2121 - val_loss: 2.0720
# Epoch 3/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.5758 - loss: 1.7808 - val_accuracy: 0.2424 - val_loss: 2.0825
# Epoch 4/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.5980 - loss: 1.3617 - val_accuracy: 0.1212 - val_loss: 2.7730
# Epoch 5/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7157 - loss: 1.0265 - val_accuracy: 0.1818 - val_loss: 2.5040
# Epoch 6/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.7198 - loss: 0.8547 - val_accuracy: 0.2424 - val_loss: 2.4735
# Epoch 7/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.8749 - loss: 0.4409 - val_accuracy: 0.3030 - val_loss: 3.6759
# Epoch 8/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9294 - loss: 0.2473 - val_accuracy: 0.3030 - val_loss: 2.7488
# Epoch 9/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9664 - loss: 0.1726 - val_accuracy: 0.2727 - val_loss: 3.4371
# Epoch 10/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9975 - loss: 0.0641 - val_accuracy: 0.2424 - val_loss: 3.7763
# Epoch 11/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9796 - loss: 0.0378 - val_accuracy: 0.3030 - val_loss: 4.3663
# Epoch 12/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 1.0000 - loss: 0.0186 - val_accuracy: 0.3636 - val_loss: 4.7085
# Epoch 13/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.3030 - val_loss: 4.7434
# Epoch 14/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.3333 - val_loss: 5.0079
# Epoch 15/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.3333 - val_loss: 5.2234
# Epoch 16/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.3333 - val_loss: 5.4087
# Epoch 17/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.3333 - val_loss: 5.5647
# Epoch 18/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.3333 - val_loss: 5.6856
# Epoch 19/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.3333 - val_loss: 5.8234
# Epoch 20/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.3333 - val_loss: 5.8493
# Epoch 21/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.3333 - val_loss: 5.8984
# Epoch 22/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.3333 - val_loss: 5.9542
# Epoch 23/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.3333 - val_loss: 5.9703
# Epoch 24/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3333 - val_loss: 6.0309
# Epoch 25/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3333 - val_loss: 6.0612
# Epoch 26/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.3333 - val_loss: 6.1255
# Epoch 27/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.3333 - val_loss: 6.1138
# Epoch 28/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.3333 - val_loss: 6.2053
# Epoch 29/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 1.0000 - loss: 9.6162e-04 - val_accuracy: 0.3333 - val_loss: 6.2229
# Epoch 30/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 1.0000 - loss: 8.0132e-04 - val_accuracy: 0.3333 - val_loss: 6.2388

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 244, 244, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 242, 242, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 121, 121, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 119, 119, 16)        │           2,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 59, 59, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 57, 57, 16)          │           2,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       1,605,760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │           1,032 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,835,642 (18.45 MB)
#  Trainable params: 1,611,880 (6.15 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,223,762 (12.30 MB)

# %%
# test using the test dataset
model.evaluate(
  val_ds
  
)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3087 - loss: 6.4149
# [6.238813877105713, 0.3333333432674408]

# %% [markdown]
# ## Lab Task
#
# * Try to tune the CNN structure to improve the accuracy
# * Try on different dataset
