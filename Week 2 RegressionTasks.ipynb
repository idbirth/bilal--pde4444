# %% [markdown]
# ### In this lab we will find the regression model for the given dataset to estimate the travel time.
# ### The Goal is to predict the arriving time (the last column) using 8 variables
# #### 'avg. Speed','Morning','Afternoon','Evening','weekend','rain','fog','distance to travel',
# ## Requirements:
# * pandas library
# * LinearRegression from sklearn
# *dataset file "DatasetLab1.csv"

# %%
# Task-1: import the libraries
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Task-2: Read the file DatasetLab1.csv, and show the first five rows
url = "DatasetLab1.csv"
data = pd.read_csv(url, names=['avg. Speed','Morning','Afternoon','Evening','weekend','rain','fog','distance to travel','travel time'])
data.head()
# Out:
#    avg. Speed  Morning  Afternoon  Evening  weekend  rain  fog  \
# 0          80        1          0        0        1     0    0
# 1          80        1          0        0        0     0    1
# 2         100        0          1        0        1     1    0
# 3          60        0          0        1        1     1    0
# 4          90        0          1        0        1     1    0
#
#    distance to travel  travel time
# 0                   5     8.750000
# 1                  10    27.500000
# 2                  30    33.000000
# 3                  19    34.000000
# 4                  22    29.666667

# %%
# Task-3: save the values of the first 8 variables in x1 and the output variable in y1

# %%
# Task-4: split the data into train and test datasets with test size = 20%
# for this use the train_test_split () function, this function will return two datasets for each x1 and y1
# xTreain, xTest, yTrain, yTest

# %%
# Task-5: standardize the data using the StandardScaler().fit_transform function

# %%
#Task_6 : apply LR model on xTrain, yTrain. then, print the r_squared, the intercept, and the slopes
# for this you need first to create the LR model then use the fit() function, visit the following link for mor
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
# Step 1: Create the model


# step 2: Train using fit


# step 3: Predict


# Step 3: Evaluate
